# %%
#Libraries import
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math
import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt

# %%
sns.set(style="whitegrid")

# %%
#Loading Dataset
data = pd.read_csv("C:/Users/WISDM/Downloads/retail_sales_dataset.csv", parse_dates=['Date'])
data
# Out:
#      Transaction ID       Date Customer ID  Gender  Age Product Category  \
# 0                 1 2023-11-24     CUST001    Male   34           Beauty
# 1                 2 2023-02-27     CUST002  Female   26         Clothing
# 2                 3 2023-01-13     CUST003    Male   50      Electronics
# 3                 4 2023-05-21     CUST004    Male   37         Clothing
# 4                 5 2023-05-06     CUST005    Male   30           Beauty
# ..              ...        ...         ...     ...  ...              ...
# 995             996 2023-05-16     CUST996    Male   62         Clothing
# 996             997 2023-11-17     CUST997    Male   52           Beauty
# 997             998 2023-10-29     CUST998  Female   23           Beauty
# 998             999 2023-12-05     CUST999  Female   36      Electronics
# 999            1000 2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# 0           3              50           150
# ...

# %%
data.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
data.shape
# Out:
# (1000, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   datetime64[ns]
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(5), object(3)
# memory usage: 70.4+ KB

# %%
#Sales Calculation
data['Sales'] = data['Quantity'] * data['Price per Unit']
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   datetime64[ns]
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
#  9   Sales             1000 non-null   int64
# dtypes: datetime64[ns](1), int64(6), object(3)
# memory usage: 78.3+ KB

# %%
#Data cleaning
missing_val = data.isnull().sum()
print("Missing values:\n", missing_val)
# Out:
# Missing values:
#  Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# Sales               0
# dtype: int64

# %%
#Descriptive Statistics
describe_stats = data.describe()
describe_stats
# Out:
#        Transaction ID                           Date         Age     Quantity  \
# count     1000.000000                           1000  1000.00000  1000.000000
# mean       500.500000  2023-07-03 00:25:55.200000256    41.39200     2.514000
# min          1.000000            2023-01-01 00:00:00    18.00000     1.000000
# 25%        250.750000            2023-04-08 00:00:00    29.00000     1.000000
# 50%        500.500000            2023-06-29 12:00:00    42.00000     3.000000
# 75%        750.250000            2023-10-04 00:00:00    53.00000     4.000000
# max       1000.000000            2024-01-01 00:00:00    64.00000     4.000000
# std        288.819436                            NaN    13.68143     1.132734
#
#        Price per Unit  Total Amount        Sales
# count     1000.000000   1000.000000  1000.000000
# mean       179.890000    456.000000   456.000000
# min         25.000000     25.000000    25.000000
# 25%         30.000000     60.000000    60.000000
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
print(data.columns)
# Out:
# Index(['Transaction ID', 'Date', 'Customer ID', 'Gender', 'Age',
#        'Product Category', 'Quantity', 'Price per Unit', 'Total Amount',
#        'Sales'],
#       dtype='object')

# %%
data.columns = data.columns.str.strip()
print(data.columns)
# Out:
# Index(['Transaction ID', 'Date', 'Customer ID', 'Gender', 'Age',
#        'Product Category', 'Quantity', 'Price per Unit', 'Total Amount',
#        'Sales'],
#       dtype='object')

# %%
# Check for missing values
missing_values = data.isnull().sum()
print("Missing Values:\n", missing_values)
# Out:
# Missing Values:
#  Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# Sales               0
# dtype: int64

# %%
# Descriptive Statistics
descriptive_stats = data.describe()
print("Descriptive Statistics:\n", descriptive_stats)
# Out:
# Descriptive Statistics:
#         Transaction ID                           Date         Age     Quantity  \
# count     1000.000000                           1000  1000.00000  1000.000000
# mean       500.500000  2023-07-03 00:25:55.200000256    41.39200     2.514000
# min          1.000000            2023-01-01 00:00:00    18.00000     1.000000
# 25%        250.750000            2023-04-08 00:00:00    29.00000     1.000000
# 50%        500.500000            2023-06-29 12:00:00    42.00000     3.000000
# 75%        750.250000            2023-10-04 00:00:00    53.00000     4.000000
# max       1000.000000            2024-01-01 00:00:00    64.00000     4.000000
# std        288.819436                            NaN    13.68143     1.132734
#
#        Price per Unit  Total Amount        Sales
# count     1000.000000   1000.000000  1000.000000
# mean       179.890000    456.000000   456.000000
# min         25.000000     25.000000    25.000000
# ...

# %%
print(type(['Date']))
# Out:
# <class 'list'>

# %%
print(data.columns)
# Out:
# Index(['Transaction ID', 'Date', 'Customer ID', 'Gender', 'Age',
#        'Product Category', 'Quantity', 'Price per Unit', 'Total Amount',
#        'Sales'],
#       dtype='object')

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
# Plot sales trends over time
plt.figure(figsize=(12, 6))
plt.plot(data['Date'], data['Sales'])
plt.title('Sales Trends Over Time')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.show()

# %%
# Customer and Product Analysis
customer_age_sales = data.groupby('Age')['Sales'].sum()
print("Sales by Customer Age Group:\n", customer_age_sales)
# Out:
# Sales by Customer Age Group:
#  Age
# 18    11215
# 19    14870
# 20     8645
# 21    12585
# 22    13700
# 23     8220
# 24     5415
# 25     9900
# 26    13980
# 27     9385
# 28     8670
# 29     6570
# 30     9790
# 31    10220
# 32     5550
# 33     6240
# 34    16785
# 35    11290
# 36     9105
# 37    11650
# 38    11100
# 39     4595
# 40     9415
# 41     5650
# 42     8500
# 43    17970
# 44     7560
# 45     6325
# 46    13090
# 47    12505
# 48     7240
# 49     5110
# 50     9845
# 51    16065
# 52     7040
# 53     9510
# 54    10505
# 55     9780
# 56     9440
# 57     9290
# 58     7395
# 59     9470
# 60    11590
# 61     6730
# 62     8120
# 63     9250
# 64     9125
# Name: Sales, dtype: int64

# %%
# Bar chart for sales by customer age group
plt.figure(figsize=(10, 6))
customer_age_sales.plot(kind='bar')
plt.title('Sales by Customer Age Group')
plt.xlabel('Customer Age Group')
plt.ylabel('Total Sales')
plt.show()

# %%
# Resample data to monthly or weekly 'TotalAmount', if applicable
#if 'TotalAmount' in data.columns:
monthly_sales = data.resample('M')['Total Amount'].sum()
monthly_sales.plot(figsize=(10,6), title='Monthly Total Amount Trends')
plt.show()
# Out:
# C:\Users\WISDM\AppData\Local\Temp\ipykernel_28192\2032246036.py:3: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_sales = data.resample('M')['Total Amount'].sum()

# %%
# Customer Analysis
plt.figure(figsize=(8, 6))
sns.countplot(x='Age', data=data)
plt.title('Customer Age Distribution')
plt.show()

# %%
# Set 'Date' as the index for time series analysis
data.set_index('Date', inplace=True)

# %%
data['Date'].nunique()
# Out:
# 345

# %%
data['Product Category'].nunique()
# Out:
# 3

# %%
data['Gender'].nunique()
# Out:
# 2

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Descriptive statistics
print(data.describe())
# Out:
#        Transaction ID         Age     Quantity  Price per Unit  Total Amount
# count     1000.000000  1000.00000  1000.000000     1000.000000   1000.000000
# mean       500.500000    41.39200     2.514000      179.890000    456.000000
# std        288.819436    13.68143     1.132734      189.681356    559.997632
# min          1.000000    18.00000     1.000000       25.000000     25.000000
# 25%        250.750000    29.00000     1.000000       30.000000     60.000000
# 50%        500.500000    42.00000     3.000000       50.000000    135.000000
# 75%        750.250000    53.00000     4.000000      300.000000    900.000000
# max       1000.000000    64.00000     4.000000      500.000000   2000.000000

# %%
cleaned_data = data.copy()

# %%
sns.scatterplot(x='Price per Unit', y='Total Amount', data=cleaned_data)
plt.title('Price/Unit vs Total Amount')
plt.xlabel('Price/Unit')
plt.ylabel('Total Amount')
plt.show()

# %%
#Product Analysis
top_products = cleaned_data.groupby('Product Category')['Quantity'].sum().sort_values(ascending=False).head(7)
plt.figure(figsize=(10, 6))
sns.barplot(x=top_products.index, y=top_products.values)
plt.title('Top 10 Products by Quantity Sold')
plt.xticks(rotation=45)
plt.show()

# %%
print(data.dtypes)
# Out:
# Transaction ID               int64
# Date                datetime64[ns]
# Customer ID                 object
# Gender                      object
# Age                          int64
# Product Category            object
# Quantity                     int64
# Price per Unit               int64
# Total Amount                 int64
# Sales                        int64
# dtype: object

# %%
data_numeric = data.select_dtypes(include=[np.number])  # Select only numeric columns 
data_numeric
# Out:
#      Transaction ID  Age  Quantity  Price per Unit  Total Amount  Sales
# 0                 1   34         3              50           150    150
# 1                 2   26         2             500          1000   1000
# 2                 3   50         1              30            30     30
# 3                 4   37         1             500           500    500
# 4                 5   30         2              50           100    100
# ..              ...  ...       ...             ...           ...    ...
# 995             996   62         1              50            50     50
# 996             997   52         3              30            90     90
# 997             998   23         4              25           100    100
# 998             999   36         3              50           150    150
# 999            1000   47         4              30           120    120
#
# [1000 rows x 6 columns]

# %%
#Heatmap for correlation matrix
correlation_matrix = data_numeric.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix Heatmap')
plt.show()
